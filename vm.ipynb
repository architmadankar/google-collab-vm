# %%
#@title Hit RUN Button to Bake Your RDP. ***sudo pass: 8081***
! wget https://raw.githubusercontent.com/freemiumboxx/debian/main/rdp.sh &> /dev/null
! chmod +x rdp.sh 
! ./rdp.sh
# Out:
# Installing RDP Be Patience...

# %% [markdown]
# #**To prevent Google Colab from disconnecting, Run this code in the browser console:**
#
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
